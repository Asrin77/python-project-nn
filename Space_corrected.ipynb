# %% [markdown]
# <a href="https://colab.research.google.com/github/Asrin77/python-project-nn/blob/main/Space_corrected.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %%
# !git clone https://github.com/Asrin77/python-project-nn.git
# Out:
# Cloning into 'python-project-nn'...
# remote: Enumerating objects: 3, done.
# remote: Counting objects: 100% (3/3), done.
# remote: Compressing objects: 100% (2/2), done.
# remote: Total 3 (delta 0), reused 3 (delta 0), pack-reused 0 (from 0)
# Receiving objects: 100% (3/3), done.

# %%
# %cd python-project-nn
# Out:
# /content/python-project-nn

# %%
# !git branch
# !git remote -v
# Out:
# * main
# origin	https://github.com/Asrin77/python-project-nn.git (fetch)
# origin	https://github.com/Asrin77/python-project-nn.git (push)
